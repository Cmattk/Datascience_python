# %%
# print in python
print('hello world!')

# comments in python
"""
This is a multi-line comment.
It can be used to describe larger sections of code.
"""
# identation
if 10 > 5:
    print('this is true')
    print("I am tab indentation")

print("I have no indentation")

# input in Python
name = input("Enter your name: ")
print("Hello,", name, "! Welcome!")

# variable
s ="Pan"
print(s)

var1 = 5
var2 = 6
output = input("enter the sum of the 2: ")
print(name,", has said the sum total is", 11,".")


x, y = input("enter your names: ").split()
print("Firstname: ", x)
print("lastname: ", y)

a, b, c = input("enter your name and age: ").split()
print("Firstname: ", a)
print("lastname: ", b)
print("Age: ", c)
# Out:
# hello world!
# this is true
# I am tab indentation
# I have no indentation
# Hello, matt ! Welcome!
# Pan
# matt , has said the sum total is 11 .
# Firstname:  mathias
# lastname:  kasina
# Firstname:  mathias
# lastname:  kasina
# Age:  25
